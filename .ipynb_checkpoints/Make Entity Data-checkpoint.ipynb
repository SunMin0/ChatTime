# %%
import pandas as pd
df = pd.read_csv('./cafe_intent_data.csv')
df['label'] = df['question']

# 먼저 예외처리 --------------------------------
except1_dict = {
    '너무 뜨겁지 않게':'O S-TEMP O',
    '뜨겁지 않게':'S-TEMP O',
    '너무 달게하지 말고':'O O O',
    '많이 달지 않게':'O O O',
    '약간 산미 나는':'O O O',
    '덜 달게':'O O',
    '비 ':'O ',
    '원샷':'O',
    '한샷':'O',
    '샷':'O',
    '테이크 아웃':'O O',
    '테이크아웃':'O',
    '새로운 메뉴':'O O',
    '세트메뉴':'O',
    '4000원':'O',
    '삼천팔백 원짜리':'O O',
    '휘핑크림':'O',
    '두유':'O',
    '설탕':'O',
    '플래시 구콘':'O O',
    ' 내야하나요':' O',
    ' 주문돼요':' O',
    '기프티콘':'O',
    '고소한 원두':'O O',
}

# 개체 ------------------------------------
entity_dict = {
    # 결제 --------------------------------
    '계산요':'S-PAY',
    '결제요':'S-PAY',
    '계산':'S-PAY',
    '결제':'S-PAY',
    
    # 메뉴 --------------------------------
    # 커피 ---------------------------- 
    '그린 티 프라푸치노':'B-COFFEE I-COFFEE E-COFFEE',
    '민트 초코 프라푸치노':'B-COFFEE I-COFFEE E-COFFEE',
    '캐러멜 프라푸치노':'B-COFFEE E-COFFEE',
    '자바칩 프라푸치노':'B-COFFEE E-COFFEE',
    '프라푸치노':'S-COFFEE',
    '카라멜마끼아또':'S-COFFEE',
    '에스프레소':'S-COFFEE',
    '카페모카':'S-COFFEE',
    '아아':'S-COFFEE',
    '디카페인 아이스 아메리카노':'B-COFFEE I-COFFEE E-COFFEE',
    '블루마운틴 아메리카노':'B-COFFEE E-COFFEE',
    '아이스아메리카노':'S-COFFEE',
    '생아메리카노':'S-COFFEE',
    '아메리카노':'S-COFFEE',
    '아메키라노':'S-COFFEE',
    '아메카노':'S-COFFEE',
    '카푸치노':'S-COFFEE',
    '화이트 모카':'B-COFFEE E-COFFEE',
    '모카 라떼':'B-COFFEE E-COFFEE',
    '모카 라테':'B-COFFEE E-COFFEE',
    '아몬드 카페 라떼':'B-COFFEE I-COFFEE E-COFFEE',
    '시그니처 초콜렛':'B-COFFEE E-COFFEE',
    '초콜릿 라떼':'B-COFFEE E-COFFEE',
    '초콜렛 라떼':'B-COFFEE E-COFFEE',
    '초코 라테':'B-COFFEE E-COFFEE',
    '초코라떼':'S-COFFEE',
    '슈크림 라테':'B-COFFEE E-COFFEE',
    '솔티치즈 카페라떼':'B-COFFEE E-COFFEE',
    '밀크티 라떼':'B-COFFEE E-COFFEE',
    '바닐라 라떼':'B-COFFEE E-COFFEE',
    '바닐라 라테':'B-COFFEE E-COFFEE',
    '바닐라라테':'S-COFFEE',
    '토피넛 라테':'B-COFFEE E-COFFEE',
    '감귤 라테':'B-COFFEE E-COFFEE',
    '돌체 라테':'B-COFFEE E-COFFEE',
    '말차 라떼':'B-COFFEE E-COFFEE',
    '말차 라테':'B-COFFEE E-COFFEE',
    '딜라이트 라테':'B-COFFEE E-COFFEE',
    '캐러멜 라테':'B-COFFEE E-COFFEE',
    '카페 라떼':'B-COFFEE E-COFFEE',
    '카페라떼':'S-COFFEE',
    '카페라테':'S-COFFEE',
    '녹차라떼':'S-COFFEE',
    '녹차라테':'S-COFFEE',
    '아이스라떼':'S-COFFEE',
    '더치 라떼':'B-COFFEE E-COFFEE',
    '더치라떼':'S-COFFEE',
    '더치 커피':'B-COFFEE E-COFFEE',
    '더치커피':'S-COFFEE',
    '소금커피':'S-COFFEE',
    '모카':'S-COFFEE',
    '더치':'S-COFFEE',
    '콜드 브루 라떼':'B-COFFEE I-COFFEE E-COFFEE',
    '콜드브루 라테':'B-COFFEE E-COFFEE',
    '콜드 브루':'B-COFFEE E-COFFEE',
    '콜드브루 커피':'B-COFFEE E-COFFEE',
    '콜드브루':'S-COFFEE',
    '아인슈페너':'S-COFFEE',
    '카라멜 마끼아또':'B-COFFEE E-COFFEE',
    '캐러멜 마키아토':'B-COFFEE E-COFFEE',
    '캐러멜마키아토':'S-COFFEE',
    '마키아토':'S-COFFEE',
    '마끼아또':'S-COFFEE',
    '돌체라떼':'S-COFFEE',
    '돌체라뗴':'S-COFFEE',
    '드립커피':'S-COFFEE',
    '밤라떼':'S-COFFEE',
    '딸기 라테':'B-COFFEE E-COFFEE',
    '바닐라딜라이트':'S-COFFEE',
    '쿠키프라페':'S-COFFEE',
    '유로드립':'S-COFFEE',
    '아포가토':'S-COFFEE',
    '아보카도':'S-COFFEE',
    '플랫 화이트':'B-COFFEE E-COFFEE',
    '오트밀 라떼':'B-COFFEE E-COFFEE',
    '카페 비엔나':'B-COFFEE E-COFFEE',
    '비엔나 커피':'B-COFFEE E-COFFEE',
    '쿠앤크 치노':'B-COFFEE E-COFFEE',
    '오늘의 커피':'B-COFFEE E-COFFEE',
    '커피':'S-COFFEE',
    '라테':'S-COFFEE',
    '라떼':'S-COFFEE',
    
    # 주스 ----------------------------
    '초코 바나나 스무디':'B-JUICE I-JUICE E-JUICE',
    '바나나 주스':'B-JUICE E-JUICE',
    '솔트 치즈':'B-JUICE E-JUICE',
    '생과일 주스':'B-JUICE E-JUICE',
    '딸기 주스':'B-JUICE E-JUICE',
    '자몽 주스':'B-JUICE E-JUICE',
    '블루베리 주스':'B-JUICE E-JUICE',
    '바나나 주스':'B-JUICE E-JUICE',
    '토마토 주스':'B-JUICE E-JUICE',
    '토마토주스':'S-JUICE',
    '딸기 에이드':'B-JUICE E-JUICE',
    '자몽 에이드':'B-JUICE E-JUICE',
    '순수 에이드':'B-JUICE E-JUICE',    
    '레몬 에이드':'B-JUICE E-JUICE',    
    '레몬에이드':'S-JUICE',
    '자몽에이드':'S-JUICE',
    '딸기주스':'S-JUICE',
    '블루베리주스':'S-JUICE',
    '과일 음료':'B-JUICE E-JUICE',
    '플랜클링레몬':'S-JUICE',
    '요거트 스무디':'B-JUICE E-JUICE',
    '딸기 스무디':'B-JUICE E-JUICE',   
    '블루베리 스무디':'B-JUICE E-JUICE',    
    '미숫가루':'S-JUICE',
    '반반주스':'S-JUICE',
    '생딸기쥬스':'S-JUICE',
    '빙수':'S-JUICE',
    '자몽 피지와':'B-JUICE E-JUICE',
    '플레인 요거트':'B-JUICE E-JUICE',
    '딸기 요거트':'B-JUICE E-JUICE',
    '딸기 바나나':'B-JUICE E-JUICE',
    '스무디':'S-JUICE',
    
    # 티 ------------------------------
    '로즈 재스민 티':'B-TEA I-TEA E-TEA',
    '얼 그레이 티':'B-TEA I-TEA E-TEA',
    '자몽차':'S-TEA',
    '자몽치':'S-TEA',
    '영귤차':'S-TEA',
    '쟈스민 차':'B-TEA E-TEA',
    '레몬 차':'B-TEA E-TEA',
    '밀크 티':'B-TEA E-TEA',
    '페퍼민트 허브티':'B-TEA E-TEA',
    '페퍼민트 티':'B-TEA E-TEA',
    '레몬 티':'B-TEA E-TEA',
    '생자몽 티':'B-TEA E-TEA',
    '허브티':'S-TEA',
    '레몬차':'S-TEA',
    '캐머마일':'S-TEA',
    '케모마일':'S-TEA',
    '카모마일':'S-TEA',
    '루이보스 밀크티':'B-TEA E-TEA',
    '루이보스':'S-TEA',
    '블랙 밀크티':'B-TEA E-TEA',
    '밀크티':'S-TEA',
    '아이스티':'S-TEA',
    '유자차':'S-TEA',
    '핫초코':'S-TEA',
    '모과차':'S-TEA',
    '물':'S-TEA',
    '홍차':'S-TEA',
    '홍자':'S-TEA',
    '녹차':'S-TEA',
            
    # 베이커리 ------------------------
    '크로크무슈':'S-BAKE',
    '애플파이':'S-BAKE',
    '치즈베이글':'S-BAKE',
    '베이글':'S-BAKE',
    '초코 마카롱':'B-BAKE E-BAKE',
    '요거트 마카롱':'B-BAKE E-BAKE',
    '딸기마카롱':'S-BAKE',
    '쿠앤크마카롱':'S-BAKE',
    '마카롱':'S-BAKE',
    '블루베리 크림 와플':'B-BAKE I-BAKE E-BAKE',
    '인절미 쏙쏙 붕어빵':'B-BAKE I-BAKE E-BAKE',
    '생크림 소프트 쉬폰':'B-BAKE I-BAKE E-BAKE',
    '과일 생크림 케이크':'B-BAKE I-BAKE E-BAKE',
    '블루베리 치즈케이크':'B-BAKE E-BAKE',
    '어니언 크림':'B-BAKE E-BAKE',
    '블루베리 케이크':'B-BAKE E-BAKE',
    '생크림 케이크':'B-BAKE E-BAKE',
    '레드벨벳 케이크':'B-BAKE E-BAKE',
    '티라미슈 케이크':'B-BAKE E-BAKE',
    '티라미수 케이크':'B-BAKE E-BAKE',
    '당근 케이크':'B-BAKE E-BAKE',
    '치즈 케이크':'B-BAKE E-BAKE',
    '뉴욕 치즈케이크':'B-BAKE E-BAKE',
    '말차 케이크':'B-BAKE E-BAKE',
    '초코 케이크':'B-BAKE E-BAKE',
    '치즈케이크':'S-BAKE',
    '초코케이크':'S-BAKE',
    '옥수수빵':'S-BAKE',
    '허니브레드':'S-BAKE',
    '단팥 도너츠':'B-BAKE E-BAKE',
    '오리지날 프레즐':'B-BAKE E-BAKE',
    '클럽 샌드위치':'B-BAKE E-BAKE',
    '튜너 샌드위치':'B-BAKE E-BAKE',
    '크랜베리 스콘':'B-BAKE E-BAKE',
    '생크림 카스텔라':'B-BAKE E-BAKE',
    '샌드위치':'S-BAKE',
    '티라미슈':'S-BAKE',
    '쿠키앤크림':'S-BAKE',
    '초콜릿':'S-BAKE',
    '스트로베리':'S-BAKE',
    '초코 쿠키':'B-BAKE E-BAKE',
    '블루베리 머핀':'B-BAKE E-BAKE',
    '초코머핀':'S-BAKE',
    '머핀':'S-BAKE',
    '보리찰떡':'S-BAKE',
    '수제와플':'S-BAKE',
    '고로케':'S-BAKE',
    '쿠키':'S-BAKE',
    '빵':'S-BAKE',
    '스콘':'S-BAKE',
    '티라미수':'S-BAKE',
    '컵케이크':'S-BAKE',
    '케이크':'S-BAKE',
    
    # 사이즈 ------------------------------
    '작은 사이즈':'B-SIZE E-SIZE',
    '작 사이즈':'B-SIZE E-SIZE',
    '레귤러 사이즈':'B-SIZE E-SIZE',
    'R사이즈':'S-SIZE',
    '숏 사이즈':'B-SIZE E-SIZE',
    '숏사이즈':'S-SIZE',
    '스몰사이즈':'S-SIZE',
    '스몰':'S-SIZE',
    '톨사이즈':'S-SIZE',
    '빅사이즈':'S-SIZE',
    '사이즈업':'S-SIZE',
    '작은사이즈':'S-SIZE',
    '큰사이즈':'S-SIZE',
    '큰 사이즈':'B-SIZE E-SIZE',
    '라지 사이즈':'B-SIZE E-SIZE',
    '라지사이즈':'S-SIZE',
    '라지':'S-SIZE',
    '사이즈 업':'B-SIZE E-SIZE',
    '톨 사이즈':'B-SIZE E-SIZE',
    '그란데 사이즈':'B-SIZE E-SIZE',
    '그란데':'S-SIZE',
    '더 큰':'B-SIZE E-SIZE',
    '큰':'S-SIZE',
    '톨':'S-SIZE',
    '벤티':'S-SIZE',
    '레귤러':'S-SIZE',
    '작은':'S-SIZE',
    '작':'S-SIZE',
    
    # 온도 --------------------------------
    '따뜻한':'S-TEMP',
    '따뜻':'S-TEMP',
    '따듯한':'S-TEMP',
    '따듯':'S-TEMP',
    '뜨거운':'S-TEMP',
    '뜨겁게요':'S-TEMP',
    '뜨겁':'S-TEMP',
    '핫 ':'S-TEMP ',
    '핫':'S-TEMP',
    '시원한':'S-TEMP',
    '시원':'S-TEMP',
    '차갑':'S-TEMP',
    '차가운':'S-TEMP',
    '차운':'S-TEMP',
    '찬':'S-TEMP',
    '아이스 ':'S-TEMP ',
    '아이스요':'S-TEMP',
    '아이스':'S-TEMP',
    
    # 수량 --------------------------------
    '둘 다':'B-COUNT E-COUNT',
    '한 병':'B-COUNT E-COUNT',
    '한 잔이':'B-COUNT E-COUNT',
    '한 잔':'B-COUNT E-COUNT',
    '두 잔':'B-COUNT E-COUNT',
    '세 잔':'B-COUNT E-COUNT',
    '네 잔':'B-COUNT E-COUNT',
    '다섯 잔':'B-COUNT E-COUNT',
    '여섯 잔':'B-COUNT E-COUNT',
    '한 조각':'B-COUNT E-COUNT',
    '두 조각':'B-COUNT E-COUNT',
    '한 개':'B-COUNT E-COUNT',
    '두 개':'B-COUNT E-COUNT',
    '세 개':'B-COUNT E-COUNT',
    '네 개':'B-COUNT E-COUNT',
    '다섯 개':'B-COUNT E-COUNT',
    '한개':'S-COUNT',
    '한잔':'S-COUNT',
    '두잔':'S-COUNT',
    '세잔':'S-COUNT',
    '네잔':'S-COUNT',
    '다섯잔':'S-COUNT',
    '두개':'S-COUNT',
    '세개':'S-COUNT',
    '네개':'S-COUNT',
    '다섯개':'S-COUNT',
    '하나':'S-COUNT',
    '둘':'S-COUNT',
    '셋':'S-COUNT',
    '넷':'S-COUNT',
    '다섯':'S-COUNT',
    '1잔':'S-COUNT',
    '2잔':'S-COUNT',
    '3잔':'S-COUNT',
    '4잔':'S-COUNT',
    '5잔':'S-COUNT',
    '1봉지':'S-COUNT',
    '1조각':'S-COUNT',
    '2조각':'S-COUNT',
    '한조각':'S-COUNT',
    '두조각':'S-COUNT',
    '1개':'S-COUNT',
    '2개':'S-COUNT',
    '3개':'S-COUNT',
    '4개':'S-COUNT',
    '5개':'S-COUNT',
    '20개':'S-COUNT',
    '30개':'S-COUNT',
    '30잔':'S-COUNT',
}

# 개체처리 후 예외처리 --------------------------------
except2_dict = {
    '텀블러':'O',
    '음료':'O',
    '사이즈':'O',
    '일반 ':'O ',
    '세트':'O',
    '데워주실 ':'O ',
    '데워':'O',
    '날씨':'O',
    '미지근':'O',
    '온도':'O',
    '얼음':'O',
    '변경':'O',
    '주문 취소':'O O',
    '주문취소':'O',
    '주문좀':'O',
    '주문':'O',
    '취소':'O',
    '추가':'O',
    '적립':'O',
    '포장':'O',
    '포크':'O',
    '포함':'O',
    '추천':'O',
    '맛':'O',
    '디카페인':'O',
    '티':'S-TEA',
    '한 번':'O O',
    '생크림':'O',
    '우유':'O',
    '휘핑빼고':'O',
    ' 휘핑 ':' O ',
}

# 시작어 ----------------------------------
start_dict = {
    '네 ':'O ',
    '아니요 ':'O ',
    '아뇨 ':'O ',
    '아니다 ':'O ',
    '아니 ':'O ',
    '그럼 ':'O ',
    '그러면 ':'O ',
    '그리고 ':'O ',
    '저는 ':'O ',
    '저 ':'O ',
    '그냥 ':'O ',
    '이제 ':'O ',
    '지금 ':'O ',
    '방금 ':'O ',
    '혹시 ':'O ',
    '죄송한데 ':'O ',
    '좋아 ':'O ',
    '아 ':'O ',
    '응 ':'O ',
    '여기 ':'O ',
    '우리 ':'O ',
    '급한 ':'O ',
    '그렇게 ':'O ',
    '어느 ':'O ',
    '가장 ':'O ',
    '그렇게까지 ':'O ',
    '겨울인데 ':'O ',
    '일단 ':'O ',
}

# 종료어 ----------------------------------
end_dict = {
    ' 좋겠습니다':' O',
    ' 좋겠어요':' O',
    ' 좋겠네요':' O',
    ' 해주세요':' O',
    ' 해주시겠어요':' O',
    '해주시겠어요':'',
    ' 해주실래요':' O',
    '해주실래요':'',
    ' 해줄래요':' O',
    ' 해줄래':' O',
    '해줄래':'',
    ' 해줘요':' O',
    ' 해줘':' O',
    '해줘':'',
    '해주세요':'',
    ' 넣어주세요':' O',
    ' 줘요':' O',
    ' 주세요':' O',
    ' 주십시오':' O',
    ' 주시지요':' O',
    ' 주실래요':' O',
    ' 주시게나':' O',
    ' 주시겠어요':' O',
    ' 낫겠어요':' O',
    ' 낫겠네요':' O',
    ' 부탁드리겠습니다':' O',
    ' 부탁드릴게요':' O',
    ' 부탁드립니다':' O',
    ' 부탁드려요':' O',
    ' 부탁합니다':' O',
    ' 부탁해요':' O',
    ' 하겠습니다':' O',
    '하겠습니다':'',
    ' 되나요':' O',
    ' 가능하실까요':' O',
    ' 가능할까요':' O',
    ' 가능한가요':' O',
    ' 가능하세요':' O',
    ' 가능해요':' O',
    ' 있어요':' O',
    ' 남아있나요':' O',
    ' 있나요':' O',
    ' 없나요':' O',
    ' 되나요':' O',
    ' 파나요':' O',
    ' 바꿀게요':' O',
    ' 바꿔주세요':' O',
    ' 주문하겠습니다':' O',
    ' 주문할게요':' O',
    ' 주문돼요':' O',
    ' 될까요':' O',
    ' 될까':' O',
    ' 추가해주세요':' O',
    ' 포장해주세요':' O',
    ' 담아주세요':' O',
    ' 있을까요':' O',
    ' 있을까':' O',
    ' 할게요':' O',
    ' 구매할게요':' O',
    ' 먹어볼게요':' O',
    ' 먹을게요':' O',
    '할게요':'',
    ' 할게':' O',
    '할게':'',
    ' 할래요':' O',
    '할래요':'',
    ' 요청드려요':' O',
    ' 요청드립니다':' O',
    ' 살게요':' O',
    ' 갈게요':' O',
    ' 싶어요':' O',
    ' 싶어':' O',
    '하고싶어':'',
    '싶어':'',
    '주세요':'',
    ' 팔아요':' O',
    ' 있죠':' O',
    '차이나요':'O',
    '먹습니다':'O',
    '먹고싶네':'O',
    '먹어요':'O',
    '먹을래':'O',
    '땡기네':'O',
}

# 조사 동사 형용사 -----------------------------
josa_dict = {    
    ' 바로 ':' O ',
    ' 먹고 ':' O ',
    ' 싶네 ':' O ',
    ' 싶네':' O ',
    ' 위에 ':' O ',
    ' 천천히 ':' O ',
    ' 반만 ':' O ',
    ' 말고 ':' O ',
    ' 달게하진 ':' O ',
    '랑요 ':' ',
    ' 쓰고 ':' O ',
    ' 안 ':' O ',
    ' 일이 ':' O ',
    ' 합쳐주시고 ':' O ',
    ' 겨울에도 ':' O ',
    ' 많은 ':' O ',
    ' 나게 ':' O ',
    ' 들어갔으면 ':' O ',
    ' 전부 ':' O ',
    '전부 ':'O ',
    ' 빼고':' O',
    ' 섞은 ':' O ',
    ' 추가 ':' O ',
    ' 함께 ':' O ',
    ' 포장 ':' O ',
    ' 종류별로 ':' O ',
    ' 기본적인 ':' O ',
    ' 나왔으면 ':' O ',
    ' 시럽 ':' O ',
    ' 별로 ':' O ',
    ' 이렇게 ':' O ',
    ' 진하게 ':' O ',
    ' 주실 ':' O ',
    ' 조금 ':' O ',
    ' 너무 ':' O ',
    ' 마시고 ':' O ',
    ' 섞은거 ':' O ',
    ' 바빠서 ':' O ',
    ' 바꿔서 ':' O ',
    ' 생겨서 ':' O ',
    ' 없어서 ':' O ',
    ' 넣어서 ':' O ',
    ' 기다릴 ':' O ',
    ' 여기서 ':' O ',
    ' 놔두고 ':' O ',
    ' 있으면 ':' O ',
    ' 종류가 ':' O ',
    ' 정도 ':' O ',
    '것도 ':'O ',
    '에도 ':' ',
    '말고도 ':'O ',
    '해도 ':'O ',
    '게도 ':' ',
    ' 걸로요':' O',
    ' 거로요':' O',
    '걸로요':'',
    '거로요':'',
    ' 거로 ':' O ',
    ' 거로':' O',
    '거로 ':' ',
    ' 걸로 ':' O ',
    ' 걸로':' O',
    '그걸로':'O',
    '걸로 ':' ',
    ' 거요':' O',
    '올려':'O',
    '거로':'',
    '걸로':'',
    '로는 ':' ',
    '거요':'',
    '했던거':'',
    '한 거':' O',
    '한거':'',
    '한게':'',
    '하게요':'',
    '하게':'',
    '게 ':' ',
    '그거랑':'O',
    ' 거랑 ':' O ',
    '그거 ':'O ',
    '이거 ':'O ',
    ' 거 ':' O ',
    '거 ':' ',
    '했던 ':' ',
    '으로요':'',
    '로요':'',
    '으로 ':' ',
    '로 ':' ',
    '로는 ':' ',
    ' 수 ':' O ',
    ' 수가 ':' O ',
    ' 줄 ':' O ',
    ' 좀 ':' O ',
    ' 좀':' O',
    '좀 ':'O ',
    '좀요':'',
    '좀':'',
    ' 하구 ':' O ',
    ' 하구요 ':' O ',
    ' 같이 ':' O ',
    '같이 ':' ',
    '이요':'',
    '이랑 ':' ',
    '랑 ':' ',
    ' 더 ':' O ',
    ' 해 ':' O ',
    '해 ':' ',
    ' 해주실 ':' O ',
    ' 하면 ':' O ',
    '하면 ':' ',
    '하고요 ':' ',
    ' 하고 ':' O ',
    '하고 ':' ',
    ' 해서 ':' O ',
    '해서 ':' ',
    '돈을':'O',
    '도 ':' ',
    ' 주시고 ':' O ',
    '했던 ':' ',
    '했던거 ':' ',
    ' 넣은 ':' O ',
    '과 ':' ',
    '은 ':' ',
    '을 ':' ',
    '를 ':' ',
    '에 ':' ',
    '씩 ':' ',
    '가 ':' ',
    ' 이 ':' O ',
    ' 우선 ':' O ',
    ' 많이 ':' O ',
    '양이 ':'O ',
    '해주신':'',
    ' 해요':' O',
    '해':'',
    '는 ':' ',
    '제일':'O',
    '만 ':' ',
    ' 할 ':' O ',
    '할 ':' ',
    '요':'',
    '로':'',
    ' 반 ':' O ',
    '반 ':' ',
    '것':'O',
    '와 ':' ',
    '이 ':'O ',
    '다른':'O',
    '먹고':'O',
}

# %%
df['label'] = df['label'].replace(except1_dict, regex=True)
df['label'] = df['label'].replace(entity_dict, regex=True)
df['label'] = df['label'].replace(except2_dict, regex=True)
df['label'] = df['label'].replace(start_dict, regex=True)
df['label'] = df['label'].replace(end_dict, regex=True)
df['label'] = df['label'].replace(josa_dict, regex=True)

# %%
print(df['label'].str.split(expand=True).stack().value_counts())
# Out:
# O           2466
# S-TEMP       529
# S-COFFEE     436
# S-COUNT      393
# S-SIZE       310
# S-BAKE       216
# B-COUNT      201
# E-COUNT      201
# S-PAY        188
# S-TEA        158
# B-SIZE       142
# E-SIZE       142
# S-JUICE      133
# B-JUICE       76
# E-JUICE       76
# E-COFFEE      65
# B-COFFEE      65
# B-BAKE        39
# E-BAKE        39
# B-TEA         17
# E-TEA         17
# I-COFFEE       6
# I-BAKE         4
# I-TEA          2
# I-JUICE        2
# dtype: int64

# %%
length = df['label'].count()
for i in range(length):
    if len(df['question'][i].split()) != len(df['label'][i].split()):
        print(i+1,'번째 행의 단어 수 가 다르다.')
        print(df['question'][i])
        print(df['label'][i])

# %%
df.to_csv("test.csv", index=False)
